# %% [markdown]
# <a href="https://colab.research.google.com/github/vonlanot/us-food-imports/blob/main/US_Food_Imports.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ------------------------------------------------------------------------------
# 1. Mount Google Drive to access your CSV files
# ------------------------------------------------------------------------------
from google.colab import drive
drive.mount('/content/drive')

# ------------------------------------------------------------------------------
# 2. Import necessary libraries
# ------------------------------------------------------------------------------
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Set display options for pandas (optional, but good for viewing dataframes)
pd.set_option('display.max_columns', None) # Display all columns
pd.set_option('display.max_rows', 100)     # Display up to 100 rows
pd.set_option('display.width', 1000)      # Adjust display width

# ------------------------------------------------------------------------------
# 3. Define the base path to data
# ------------------------------------------------------------------------------
base_path = '/content/drive/My Drive/Colab Notebooks/My Data/US_Food_Imports/'

# ------------------------------------------------------------------------------
# 4. Load each cleaned CSV into a separate Pandas DataFrame with 'latin1' encoding
# ------------------------------------------------------------------------------

# Monetary Value Data
df_monetary_value = pd.read_csv(base_path + 'us_food_imports_monetary.csv', encoding='latin1')

# Quantity Data
df_quantity = pd.read_csv(base_path + 'us_food_imports_quantity.csv', encoding='latin1')

# Price Rate Data
df_price_rate = pd.read_csv(base_path + 'us_food_imports_price_rate.csv', encoding='latin1')

# Percentage Data
df_percentage = pd.read_csv(base_path + 'us_food_imports_percentage.csv', encoding='latin1')

# ------------------------------------------------------------------------------
# 5. Display the first few rows and info for each DataFrame to confirm loading
# ------------------------------------------------------------------------------
print("--- df_monetary_value ---")
print(df_monetary_value.head())
print(df_monetary_value.info())

print("\n--- df_quantity ---")
print(df_quantity.head())
print(df_quantity.info())

print("\n--- df_price_rate ---")
print(df_price_rate.head())
print(df_price_rate.info())

print("\n--- df_percentage ---")
print(df_percentage.head())
print(df_percentage.info())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# --- df_monetary_value ---
#               Commodity        Country        UOM Category SubCategory  YearNum  FoodValue
# 0    Total live animals         CANADA  Million $  Animals       Foods     1999      876.9
# 1    Total live animals         MEXICO  Million $  Animals       Foods     1999      292.2
# 2    Total live animals  REST OF WORLD  Million $  Animals       Foods     1999        0.1
# 3  Bovine animals, live         CANADA  Million $  Animals       Foods     1999      639.0
# 4  Bovine animals, live         MEXICO  Million $  Animals       Foods     1999      292.1
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13780 entries, 0 to 13779
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Commodity    13780 non-null  object
# ...
